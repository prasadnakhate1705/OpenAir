# %% [markdown]
# # Load JSONL into MongoDB (PyMongo) — Flights Project
#
# This notebook imports the cleaned JSONL files into MongoDB with **proper BSON Date types** and **safe upsert behavior**.
#
# **What it does:**
# - Parameterize paths and Mongo connection
# - Read `flights_clean_10d.jsonl` and `aircraft_10d.jsonl`
# - Parse ISO timestamps to `datetime`
# - **Upsert** flights by `(icao24, departure_time)`
# - **Upsert** aircraft by `icao24` using **sparse updates** (won’t overwrite non-null DB values with nulls)
# - Sanity checks: counts and sample docs
#
# > Run this from your repo root kernel in VS Code, with your `adt` virtual environment selected.

# %%
# 🔧 Parameters — adjust as needed

# Where your JSONL files live (relative to repo root)
FLIGHTS_FILE = "../data_enriched/flights_clean_10d.jsonl"
AIRCRAFT_FILE = "../data_enriched/aircraft_10d.jsonl"

# MongoDB connection
MONGO_URI = "mongodb://localhost:27017"
DB_NAME = "openair"

# Safe upsert behavior for aircraft:
# - If True: only $set non-null fields (prevents wiping existing values with None)
# - If False: $set everything as-is (may overwrite values with None)
AIRCRAFT_SPARSE_UPSERT = True

FLIGHTS_FILE, AIRCRAFT_FILE, MONGO_URI, DB_NAME, AIRCRAFT_SPARSE_UPSERT
# Out:
# ('../data_enriched/flights_clean_10d.jsonl',
#  '../data_enriched/aircraft_10d.jsonl',
#  'mongodb://localhost:27017',
#  'openair',
#  True)

# %%
# 📦 Imports (install in your venv if missing: pip install pymongo)
from pymongo import MongoClient, UpdateOne
from datetime import datetime
import json, os, itertools

print("PyMongo ready")
# Out:
# PyMongo ready

# %% [markdown]
# ## Helpers

# %%
def iso_to_dt(s: str):
    """Parse ISO-8601 string to datetime (handles trailing 'Z')."""
    if s is None:
        return None
    if s.endswith('Z'):
        s = s.replace('Z', '+00:00')
    return datetime.fromisoformat(s)

def non_null_set(doc: dict, allowed_keys):
    """Return a dict with only non-null values for the allowed keys."""
    payload = {}
    for k in allowed_keys:
        v = doc.get(k, None)
        if v is not None and str(v) not in ("NaT", "None"):
            payload[k] = v
    return payload

# %% [markdown]
# ## Connect to MongoDB

# %%
client = MongoClient(MONGO_URI)
db = client[DB_NAME]
db.name
# Out:
# 'openair'

# %% [markdown]
# ## Load & Upsert — Flights

# %%
def chunked(seq, size):
    for i in range(0, len(seq), size):
        yield seq[i:i+size]

# %%
# Load & Upsert — Flights (BATCHED)
from pymongo import UpdateOne
import json

BATCH = 1000  # 1000–2000 is usually safe; reduce to 500 if you still see the error

ops = []
n_read = 0

with open(FLIGHTS_FILE, "r", encoding="utf-8") as f:
    for line in f:
        n_read += 1
        doc = json.loads(line)
        # Cast ISO strings to datetime
        doc["departure_time"] = iso_to_dt(doc["departure_time"])
        doc["arrival_time"]   = iso_to_dt(doc["arrival_time"])
        # Upsert key
        key = {"icao24": doc["icao24"], "departure_time": doc["departure_time"]}
        ops.append(UpdateOne(key, {"$set": doc}, upsert=True))

print(f"Prepared {len(ops)} upserts for flights (read {n_read} lines).")

upserted = modified = 0
for i, chunk in enumerate(chunked(ops, BATCH), start=1):
    res = db.flights.bulk_write(chunk, ordered=False)
    upserted += res.upserted_count
    modified += res.modified_count
    print(f"[Flights] Batch {i}: upserted={res.upserted_count}, modified={res.modified_count}")

print("Flights totals -> upserted:", upserted, "| modified:", modified)
# Out:
# Prepared 610535 upserts for flights (read 610535 lines).
# [Flights] Batch 1: upserted=453, modified=3
# [Flights] Batch 2: upserted=368, modified=0
# [Flights] Batch 3: upserted=370, modified=1
# [Flights] Batch 4: upserted=352, modified=1
# [Flights] Batch 5: upserted=398, modified=1
# [Flights] Batch 6: upserted=424, modified=7
# [Flights] Batch 7: upserted=391, modified=0
# [Flights] Batch 8: upserted=363, modified=0
# [Flights] Batch 9: upserted=341, modified=5
# [Flights] Batch 10: upserted=396, modified=0
# [Flights] Batch 11: upserted=432, modified=11
# [Flights] Batch 12: upserted=313, modified=0
# [Flights] Batch 13: upserted=474, modified=0
# [Flights] Batch 14: upserted=422, modified=11
# [Flights] Batch 15: upserted=365, modified=2
# [Flights] Batch 16: upserted=414, modified=6
# [Flights] Batch 17: upserted=340, modified=1
# [Flights] Batch 18: upserted=369, modified=2
# [Flights] Batch 19: upserted=465, modified=4
# [Flights] Batch 20: upserted=405, modified=5
# [Flights] Batch 21: upserted=416, modified=0
# [Flights] Batch 22: upserted=422, modified=3
# [Flights] Batch 23: upserted=377, modified=5
# [Flights] Batch 24: upserted=411, modified=7
# [Flights] Batch 25: upserted=410, modified=3
# [Flights] Batch 26: upserted=391, modified=7
# [Flights] Batch 27: upserted=389, modified=8
# [Flights] Batch 28: upserted=432, modified=4
# [Flights] Batch 29: upserted=393, modified=4
# [Flights] Batch 30: upserted=440, modified=4
# [Flights] Batch 31: upserted=357, modified=6
# [Flights] Batch 32: upserted=363, modified=1
# [Flights] Batch 33: upserted=381, modified=4
# [Flights] Batch 34: upserted=416, modified=6
# [Flights] Batch 35: upserted=450, modified=4
# [Flights] Batch 36: upserted=370, modified=7
# [Flights] Batch 37: upserted=402, modified=12
# [Flights] Batch 38: upserted=370, modified=4
# [Flights] Batch 39: upserted=363, modified=7
# [Flights] Batch 40: upserted=314, modified=5
# [Flights] Batch 41: upserted=402, modified=9
# [Flights] Batch 42: upserted=423, modified=3
# [Flights] Batch 43: upserted=315, modified=12
# [Flights] Batch 44: upserted=437, modified=4
# [Flights] Batch 45: upserted=322, modified=1
# [Flights] Batch 46: upserted=393, modified=0
# [Flights] Batch 47: upserted=385, modified=6
# [Flights] Batch 48: upserted=392, modified=13
# [Flights] Batch 49: upserted=380, modified=1
# [Flights] Batch 50: upserted=339, modified=9
# [Flights] Batch 51: upserted=350, modified=7
# [Flights] Batch 52: upserted=353, modified=9
# [Flights] Batch 53: upserted=394, modified=3
# [Flights] Batch 54: upserted=407, modified=1
# [Flights] Batch 55: upserted=352, modified=12
# [Flights] Batch 56: upserted=386, modified=13
# [Flights] Batch 57: upserted=458, modified=4
# [Flights] Batch 58: upserted=360, modified=3
# [Flights] Batch 59: upserted=387, modified=0
# [Flights] Batch 564: upserted=1000, modified=0
# [Flights] Batch 565: upserted=1000, modified=0
# [Flights] Batch 566: upserted=1000, modified=0
# [Flights] Batch 567: upserted=1000, modified=0
# [Flights] Batch 568: upserted=1000, modified=0
# [Flights] Batch 569: upserted=1000, modified=0
# [Flights] Batch 570: upserted=1000, modified=0
# [Flights] Batch 571: upserted=1000, modified=0
# [Flights] Batch 572: upserted=1000, modified=0
# [Flights] Batch 573: upserted=1000, modified=0
# [Flights] Batch 574: upserted=1000, modified=0
# [Flights] Batch 575: upserted=1000, modified=0
# [Flights] Batch 576: upserted=1000, modified=0
# [Flights] Batch 577: upserted=1000, modified=0
# [Flights] Batch 578: upserted=1000, modified=0
# [Flights] Batch 579: upserted=1000, modified=0
# [Flights] Batch 580: upserted=1000, modified=0
# [Flights] Batch 581: upserted=1000, modified=0
# [Flights] Batch 582: upserted=1000, modified=0
# [Flights] Batch 583: upserted=1000, modified=0
# [Flights] Batch 584: upserted=1000, modified=0
# [Flights] Batch 585: upserted=1000, modified=0
# [Flights] Batch 586: upserted=1000, modified=0
# [Flights] Batch 587: upserted=1000, modified=0
# [Flights] Batch 588: upserted=1000, modified=0
# [Flights] Batch 589: upserted=1000, modified=0
# [Flights] Batch 590: upserted=1000, modified=0
# [Flights] Batch 591: upserted=1000, modified=0
# [Flights] Batch 592: upserted=1000, modified=0
# [Flights] Batch 593: upserted=1000, modified=0
# [Flights] Batch 594: upserted=1000, modified=0
# [Flights] Batch 595: upserted=1000, modified=0
# [Flights] Batch 596: upserted=1000, modified=0
# [Flights] Batch 597: upserted=1000, modified=0
# [Flights] Batch 598: upserted=1000, modified=0
# [Flights] Batch 599: upserted=1000, modified=0
# [Flights] Batch 600: upserted=1000, modified=0
# [Flights] Batch 601: upserted=1000, modified=0
# [Flights] Batch 602: upserted=1000, modified=0
# [Flights] Batch 603: upserted=1000, modified=0
# [Flights] Batch 604: upserted=1000, modified=0
# [Flights] Batch 605: upserted=1000, modified=0
# [Flights] Batch 606: upserted=1000, modified=0
# [Flights] Batch 607: upserted=1000, modified=0
# [Flights] Batch 608: upserted=1000, modified=0
# [Flights] Batch 609: upserted=1000, modified=0
# [Flights] Batch 610: upserted=1000, modified=0
# [Flights] Batch 611: upserted=535, modified=0
# Flights totals -> upserted: 572519 | modified: 290

# %% [markdown]
# ## Load & Upsert — Aircraft (sparse by default)

# %%
# Load & Upsert — Aircraft (BATCHED, sparse upsert)
from pymongo import UpdateOne
import json
from datetime import datetime

BATCH = 1000  # reduce if you still see message size errors

ops = []
n_read = 0

with open(AIRCRAFT_FILE, "r", encoding="utf-8") as f:
    for line in f:
        n_read += 1
        raw = json.loads(line)

        # Base doc and optional last_seen parsing
        doc = {"icao24": raw.get("icao24")}
        if raw.get("last_seen"):
            try:
                s = raw["last_seen"]
                if s.endswith('Z'):
                    s = s.replace('Z', '+00:00')
                doc["last_seen"] = datetime.fromisoformat(s)
            except Exception:
                pass

        key = {"icao24": raw.get("icao24")}
        update = {"$setOnInsert": {"icao24": raw.get("icao24")}}

        if AIRCRAFT_SPARSE_UPSERT:
            # Only set non-null values to avoid clobbering known fields with nulls
            set_payload = non_null_set({**raw, **doc}, ["registration","model","typecode","last_seen"])
            if set_payload:
                update["$set"] = set_payload
        else:
            # Blind set (may overwrite with nulls)
            update["$set"] = {k: raw.get(k) for k in ["registration","model","typecode"] if k in raw}
            if "last_seen" in doc:
                update["$set"]["last_seen"] = doc["last_seen"]

        ops.append(UpdateOne(key, update, upsert=True))

print(f"Prepared {len(ops)} upserts for aircraft (read {n_read} lines).")

upserted = modified = 0
for i, chunk in enumerate(chunked(ops, BATCH), start=1):
    res = db.aircraft.bulk_write(chunk, ordered=False)
    upserted += res.upserted_count
    modified += res.modified_count
    print(f"[Aircraft] Batch {i}: upserted={res.upserted_count}, modified={res.modified_count}")

print("Aircraft totals -> upserted:", upserted, "| modified:", modified)
# Out:
# Prepared 75306 upserts for aircraft (read 75306 lines).
# [Aircraft] Batch 1: upserted=1000, modified=0
# [Aircraft] Batch 2: upserted=1000, modified=0
# [Aircraft] Batch 3: upserted=1000, modified=0
# [Aircraft] Batch 4: upserted=1000, modified=0
# [Aircraft] Batch 5: upserted=1000, modified=0
# [Aircraft] Batch 6: upserted=1000, modified=0
# [Aircraft] Batch 7: upserted=1000, modified=0
# [Aircraft] Batch 8: upserted=1000, modified=0
# [Aircraft] Batch 9: upserted=1000, modified=0
# [Aircraft] Batch 10: upserted=1000, modified=0
# [Aircraft] Batch 11: upserted=1000, modified=0
# [Aircraft] Batch 12: upserted=1000, modified=0
# [Aircraft] Batch 13: upserted=1000, modified=0
# [Aircraft] Batch 14: upserted=1000, modified=0
# [Aircraft] Batch 15: upserted=1000, modified=0
# [Aircraft] Batch 16: upserted=1000, modified=0
# [Aircraft] Batch 17: upserted=1000, modified=0
# [Aircraft] Batch 18: upserted=1000, modified=0
# [Aircraft] Batch 19: upserted=1000, modified=0
# [Aircraft] Batch 20: upserted=1000, modified=0
# [Aircraft] Batch 21: upserted=1000, modified=0
# [Aircraft] Batch 22: upserted=1000, modified=0
# [Aircraft] Batch 23: upserted=1000, modified=0
# [Aircraft] Batch 24: upserted=1000, modified=0
# [Aircraft] Batch 25: upserted=1000, modified=0
# [Aircraft] Batch 26: upserted=1000, modified=0
# [Aircraft] Batch 27: upserted=1000, modified=0
# [Aircraft] Batch 28: upserted=1000, modified=0
# [Aircraft] Batch 29: upserted=1000, modified=0
# [Aircraft] Batch 30: upserted=1000, modified=0
# [Aircraft] Batch 31: upserted=1000, modified=0
# [Aircraft] Batch 32: upserted=1000, modified=0
# [Aircraft] Batch 33: upserted=1000, modified=0
# [Aircraft] Batch 34: upserted=1000, modified=0
# [Aircraft] Batch 35: upserted=1000, modified=0
# [Aircraft] Batch 36: upserted=1000, modified=0
# [Aircraft] Batch 37: upserted=1000, modified=0
# [Aircraft] Batch 38: upserted=1000, modified=0
# [Aircraft] Batch 39: upserted=1000, modified=0
# [Aircraft] Batch 40: upserted=1000, modified=0
# [Aircraft] Batch 41: upserted=1000, modified=0
# [Aircraft] Batch 42: upserted=1000, modified=0
# [Aircraft] Batch 43: upserted=1000, modified=0
# [Aircraft] Batch 44: upserted=1000, modified=0
# [Aircraft] Batch 45: upserted=1000, modified=0
# [Aircraft] Batch 46: upserted=1000, modified=0
# [Aircraft] Batch 47: upserted=1000, modified=0
# [Aircraft] Batch 48: upserted=1000, modified=0
# [Aircraft] Batch 49: upserted=1000, modified=0
# [Aircraft] Batch 50: upserted=1000, modified=0
# [Aircraft] Batch 51: upserted=1000, modified=0
# [Aircraft] Batch 52: upserted=1000, modified=0
# [Aircraft] Batch 53: upserted=1000, modified=0
# [Aircraft] Batch 54: upserted=1000, modified=0
# [Aircraft] Batch 55: upserted=1000, modified=0
# [Aircraft] Batch 56: upserted=1000, modified=0
# [Aircraft] Batch 57: upserted=1000, modified=0
# [Aircraft] Batch 58: upserted=1000, modified=0
# [Aircraft] Batch 59: upserted=1000, modified=0
# [Aircraft] Batch 60: upserted=1000, modified=0
# [Aircraft] Batch 61: upserted=1000, modified=0
# [Aircraft] Batch 62: upserted=1000, modified=0
# [Aircraft] Batch 63: upserted=1000, modified=0
# [Aircraft] Batch 64: upserted=1000, modified=0
# [Aircraft] Batch 65: upserted=1000, modified=0
# [Aircraft] Batch 66: upserted=1000, modified=0
# [Aircraft] Batch 67: upserted=1000, modified=0
# [Aircraft] Batch 68: upserted=1000, modified=0
# [Aircraft] Batch 69: upserted=1000, modified=0
# [Aircraft] Batch 70: upserted=1000, modified=0
# [Aircraft] Batch 71: upserted=1000, modified=0
# [Aircraft] Batch 72: upserted=1000, modified=0
# [Aircraft] Batch 73: upserted=1000, modified=0
# [Aircraft] Batch 74: upserted=1000, modified=0
# [Aircraft] Batch 75: upserted=1000, modified=0
# [Aircraft] Batch 76: upserted=306, modified=0
# Aircraft totals -> upserted: 75306 | modified: 0

# %% [markdown]
# ## Sanity Checks

# %%
print("flights:", db.flights.count_documents({}))
print("aircraft:", db.aircraft.count_documents({}))

print("\nSample flight:")
print(db.flights.find_one() or {})

print("\nSample aircraft:")
print(db.aircraft.find_one() or {})
# Out:
# flights: 610535
# aircraft: 75306
#
# Sample flight:
# {'_id': ObjectId('6910f4b9832a6b7e9fc66d00'), 'departure_time': datetime.datetime(2022, 9, 1, 8, 39, 54), 'icao24': '44cdc6', 'arrival_time': datetime.datetime(2022, 9, 1, 10, 33, 25), 'callsign': 'BEL8DG', 'duration_min': 114, 'estarrivalairport': 'EBBR', 'estdepartureairport': 'LIRF', 'firstseen': 1662021594.0, 'ingest_date': '2022-09-01', 'lastseen': 1662028405, 'model': 'A320 214', 'registration': 'OO-SNF', 'typecode': 'A320'}
#
# Sample aircraft:
# {'_id': ObjectId('691103c1832a6b7e9fd0b428'), 'icao24': '000001', 'last_seen': datetime.datetime(2022, 9, 9, 20, 46, 37), 'model': 'Antonov 2', 'registration': 'SP-FGR', 'typecode': 'AN2'}
